# %%
from Bludiste_knihovna import *

# %%
bludiste=Bludiste.nacteni_z_csv("Data/data1.csv")
bludiste.grid
# Out:
# array([[False, False,  True, ...,  True,  True,  True],
#        [False, False, False, ..., False, False,  True],
#        [ True,  True, False, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ...,  True,  True, False],
#        [ True,  True,  True, ...,  True,  True, False],
#        [ True,  True,  True, ..., False, False, False]], shape=(50, 50))

# %%
inc=incidencni_matice(bludiste)

# %%
cesta=nejkratsi_cesta(inc)

# %%
cesta
# Out:
# [0,
#  np.int64(1),
#  np.int64(25),
#  np.int64(26),
#  np.int64(50),
#  np.int64(72),
#  np.int64(73),
#  np.int64(74),
#  np.int64(75),
#  np.int64(76),
#  np.int64(77),
#  np.int64(98),
#  np.int64(99),
#  np.int64(117),
#  np.int64(139),
#  np.int64(140),
#  np.int64(141),
#  np.int64(142),
#  np.int64(165),
#  np.int64(166),
#  np.int64(189),
#  np.int64(209),
#  np.int64(236),
#  np.int64(262),
#  np.int64(282),
#  np.int64(283),
#  np.int64(284),
#  np.int64(285),
#  np.int64(307),
#  np.int64(308),
#  np.int64(309),
#  np.int64(310),
#  np.int64(329),
#  np.int64(353),
#  np.int64(354),
#  np.int64(380),
#  np.int64(401),
#  np.int64(421),
#  np.int64(422),
#  np.int64(446),
#  np.int64(447),
#  np.int64(448),
#  np.int64(466),
#  np.int64(491),
#  np.int64(514),
#  np.int64(536),
#  np.int64(558),
#  np.int64(559),
#  np.int64(560),
#  np.int64(582),
#  np.int64(604),
#  np.int64(626),
#  np.int64(627),
#  np.int64(628),
#  np.int64(650),
#  np.int64(671),
# ...

# %%
vrcholy = [
    (i, j)
    for i in range(bludiste.grid.shape[0])
    for j in range(bludiste.grid.shape[1])
    if not bludiste.grid[i, j]]

# %%
bludiste1=generuj(25, "prazdne")

# %%
bludiste1.grid
# Out:
# array([[False, False, False,  True, False,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True, False,  True, False,
#          True,  True, False, False,  True,  True, False],
#        [ True,  True, False, False, False, False,  True,  True, False,
#          True, False, False, False,  True,  True,  True, False, False,
#          True,  True,  True,  True,  True,  True,  True],
#        [ True, False,  True,  True, False,  True, False,  True,  True,
#          True, False,  True,  True,  True,  True, False,  True,  True,
#          True,  True, False,  True,  True,  True, False],
#        [ True,  True,  True, False, False,  True,  True,  True,  True,
#          True,  True,  True,  True, False, False,  True,  True, False,
#          True,  True,  True,  True, False,  True,  True],
#        [False,  True, False, False, False,  True,  True, False,  True,
#          True, False, False, False, False,  True, False,  True,  True,
# ...

# %%
inc1=incidencni_matice(bludiste1)

# %%
cesta1=nejkratsi_cesta(inc1)

# %%
vrcholy1 = [
    (i, j)
    for i in range(bludiste1.grid.shape[0])
    for j in range(bludiste1.grid.shape[1])
    if not bludiste1.grid[i, j]]

# %%
vykresli_cestu(bludiste, cesta, vrcholy)

# %%
vykresli_cestu(bludiste1, cesta1, vrcholy1)
